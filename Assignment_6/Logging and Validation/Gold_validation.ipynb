# %%
# %sql
SELECT SUM(total_amount_usd)
FROM silver_sales_transactions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SUM(total_amount_usd)</th></tr></thead><tbody><tr><td>4.4764802E7</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(total_revenue_usd)
FROM gold_daily_sales_summary;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SUM(total_revenue_usd)</th></tr></thead><tbody><tr><td>4.4764802E7</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(DISTINCT transaction_id)
FROM silver_sales_transactions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(DISTINCTtransaction_id)</th></tr></thead><tbody><tr><td>30000</td></tr></tbody></table></div>

# %%
# %sql
SELECT SUM(total_transactions)
FROM gold_daily_sales_summary;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SUM(total_transactions)</th></tr></thead><tbody><tr><td>30000</td></tr></tbody></table></div>

# %%
# %sql
SELECT product_id, SUM(total_amount_usd)
FROM silver_sales_transactions
GROUP BY product_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT product_id, total_revenue_usd
FROM gold_product_performance;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DROP TABLE gold_monthly_revenue_by_region;
